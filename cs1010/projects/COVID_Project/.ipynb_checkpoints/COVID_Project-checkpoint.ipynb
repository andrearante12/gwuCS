# %% [markdown]
# # CS 1010 Guided Python Project

# %% [markdown]
# ### Instructor:
# **Prof. Kartik Bulusu [CS & MAE]**
#
# #### GTA:
# **Oscar Southwell**
#
# #### UTA:
# **Sameen Ahmad, Talia Novack**
#
# #### LA:
# **Manue Alaimo, Selman Eris, Saif Alzaabi, Gustavo Londono, Amy Longua, Pravin Khanal**
#
# #### Grader:
# **Rutvik Solanki**

# %% [markdown]
# The COVID-19 virus was first identified in Wuhan, Hubei, China in December of 2019. The outbreak spread and quickly resulted in a worldwide pandemic. Affected countries have varying degrees of infection rates and death rates, as well as different time frames in which the virus "peaked", and caused an increase in cases.
#
# In this project, we will take a look at data collected daily starting in January 2020 up until the end of August 2020 and analyze it using the pandas library. In addition, we will be able to plot some of the data using matplotlib.
#
# Data sources:
#
# https://github.com/CSSEGISandData
#
# https://github.com/sakshijain98/Covid-19-Data-Anaylsis-using-Python
#
# https://ourworldindata.org/coronavirus/country/united-states?country=~USA

# %% [markdown]
# ### Instructions
#
# #### General Project Guidelines:
# You are provided a data file `covid19_Confirmed_dataset_WORLD.csv` that is required to complete this project.
#
# The project is designed to walk you step by step through this data analysis process.
#
# You may add cells in the notebook if you wish, but please complete all cells!
#
# #### Submission Guidlines:
# Like the homework assignments, there is no formal submission for the project. Work on this project and submit it through Blackboard

# %%
#Your name goes here!
name1 = 'Andre Arante'

print('COVID Project is submitted by ' + name1)
# Out:
# COVID Project is submitted by Andre Arante

# %% [markdown]
# ### Step 1: Import Libraries

# %% [markdown]
# For this project, we will be using three libraries that we have already seen in class - **numpy**, **matplotlib**, and **pandas**.
#
# Please import your libraries in the cell below!
#
# **Hint:** give the libraries shortened names to save you some time typing e.g. `numpy as np`

# %%
# YOUR CODE HERE
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ### Step 2: Import COVID19 dataset from the provided CSV file

# %% [markdown]
# Using the `pd.read_csv()` function, import the csv file (located in the project folder) into this DeepNote notebook. Save the file as a variable called `corona_dataset_csv`. Please take a look at the preview of the file using the `.head()` command.
#
# **Hint:** Review the Python Demo covering pandas for these steps

# %%
# YOUR CODE HERE
df = pd.read_csv("covid19_Confirmed_dataset_WORLD.csv")
df.head()
# Out:
#   Country/Region       Lat       Long  1/22/2020  1/23/2020  1/24/2020  \
# 0    Afghanistan  33.93911  67.709953          0          0          0
# 1        Albania  41.15330  20.168300          0          0          0
# 2        Algeria  28.03390   1.659600          0          0          0
# 3        Andorra  42.50630   1.521800          0          0          0
# 4         Angola -11.20270  17.873900          0          0          0
#
#    1/25/2020  1/26/2020  1/27/2020  1/28/2020  ...  8/21/2020  8/22/2020  \
# 0          0          0          0          0  ...      37894      37953
# 1          0          0          0          0  ...       8119       8275
# 2          0          0          0          0  ...      40667      41068
# 3          0          0          0          0  ...       1045       1045
# 4          0          0          0          0  ...       2068       2134
#
#    8/23/2020  8/24/2020  8/25/2020  8/26/2020  8/27/2020  8/28/2020  \
# ...

# %% [markdown]
# Find the size of the dataframe by using the `.shape` function

# %%
# YOUR CODE HERE
df.shape
# Out:
# (267, 225)

# %% [markdown]
# ### Step 3. Delete unnecessary columns

# %% [markdown]
# Based on the preview of the data we saw above, some of the columns of data will not be of interest to us. Namely, these are the `latitude` and `longitude` coordinates.
#
# Here, we are going to remove those columns from our dataframe using the following command:

# %%
#run this cell to drop the data! (with Shift+Enter)
df.drop(['Lat','Long'], axis=1, inplace=True)

# %% [markdown]
# Preview of the dataframe using the `.head()` command

# %%
# YOUR CODE HERE
df.head(10)
# Out:
#         Country/Region  1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# 0          Afghanistan          0          0          0          0          0
# 1              Albania          0          0          0          0          0
# 2              Algeria          0          0          0          0          0
# 3              Andorra          0          0          0          0          0
# 4               Angola          0          0          0          0          0
# 5  Antigua and Barbuda          0          0          0          0          0
# 6            Argentina          0          0          0          0          0
# 7              Armenia          0          0          0          0          0
# 8            Australia          0          0          0          0          0
# 9            Australia          0          0          0          0          3
#
#    1/27/2020  1/28/2020  1/29/2020  1/30/2020  ...  8/21/2020  8/22/2020  \
# ...

# %% [markdown]
# ## What did you learn about the data after running code in the cell(s) above ?
#
# **Note**: The amount of columns has now decreased to 223 from 225
#
# ---

# %% [markdown]
# **YOUR ANSWER HERE**. covid cases first started August 2020

# %% [markdown]
# ---
# ### Step 4. Aggregate the rows by the country

# %% [markdown]
# Notice the ninth and tenth entries (listed with the indexes `8` and `9`) of the dataframe are both listed as `Australia`. But why?
#
# The data in that column is titled Country/Region, which means some of the rows may repeat if multiple regions of a country reports cases of the virus.
#
# You can imagine this as the USA reporting 50 regions, and therefore having 50 rows: one for each state. We want to clean this up to make the data more concise. We can do this by adding the regions of the same countries together.
#
#
# Use the `.groupby("Column name")` to group countries with multiple data entries together. Remember that the name of the dataframe is placed before the `.groupby()` command. Please save this variable as `corona_dataset_aggregated`.

# %%
# YOUR CODE HERE
corona_dataset_aggregated = df.groupby("Country/Region")

# %% [markdown]
# Now Sum the aggregated data set by using the `.sum()` command. Save the variable as `corona_dataset_aggregated_sum`.You can use the `.head()` command again to take a look at the new and concise data frame

# %%
# YOUR CODE HERE
corona_dataset_aggregated_sum = corona_dataset_aggregated.sum()
corona_dataset_aggregated_sum.head()
# Out:
#                 1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# Country/Region
# Afghanistan             0          0          0          0          0
# Albania                 0          0          0          0          0
# Algeria                 0          0          0          0          0
# Andorra                 0          0          0          0          0
# Angola                  0          0          0          0          0
#
#                 1/27/2020  1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  \
# Country/Region                                                         ...
# Afghanistan             0          0          0          0          0  ...
# Albania                 0          0          0          0          0  ...
# Algeria                 0          0          0          0          0  ...
# Andorra                 0          0          0          0          0  ...
# Angola                  0          0          0          0          0  ...
#
# ...

# %% [markdown]
# ## What did you learn about the data after running code in the cell(s) above?
#
# Notice the `Australia` rows have been combined now into one row.
#
# ---

# %% [markdown]
# **YOUR ANSWER HERE**. We need to clean up the data before we can do anything with it

# %% [markdown]
# ---
# Since we used `.head()` to view the dataframe, we can only see the first 10 rows listed. We want to know the amount of rows we now have after summing countries/regions together. Recall that we found the original shape of the dataframe to be 267 rows and 225 columns. Find the new shape of the dataframe!

# %%
# YOUR CODE HERE
corona_dataset_aggregated_sum.shape
# Out:
# (189, 222)

# %% [markdown]
# ## What did you learn about the data after running code in the cell above?
#
# **Note:** The new number of rows should be less than 267
#
# ---

# %% [markdown]
# **YOUR ANSWER HERE**. The new number of rows is 189

# %% [markdown]
# ---
# ### Step 5. Visualize the data

# %% [markdown]
# Now, we will visually analyze the data we reorganized using plots. Make sure to review this code and understand what we are doing to get the results, as you will be doing something similar at the end of this exercise.
#
# Below, we will take the countries with the current highest infection numbers and plot them.
#
# The top three countries are `Brazil`, `India`, and the `United States of America`. We will create a variable for each of them named `country_time_series`, which will be set to the time and infection numbers taken from the dataframe. We will also grab the information from `China` to compare.
#
# To extract these values from the dataframe, we can use the `.loc['Country Name']` command taken from pandas. This command makes it very simple to gather the information we want to look at!

# %%
#Example code for brazil_time_series is shown below
brazil_time_series = corona_dataset_aggregated_sum.loc['Brazil']

# %% [markdown]
# From the code provided in the previous cell, extract the data pertaining to the infection numbers for `United States`, `China`, and `India` in the cell below

# %%
# YOUR CODE HERE
us_time_series = corona_dataset_aggregated_sum.loc['United States']
china_time_series = corona_dataset_aggregated_sum.loc['Brazil']
india_time_series = corona_dataset_aggregated_sum.loc['India']

# %% [markdown]
# Complete the code using your knowledge of **matplotlib** to plot data pertaining to the infection numbers of `Brazil`, `India` and `USA` in the cell below. Make sure to include a legend and set up the x-axis to label the beginning of every month

# %%
us_time_series.plot(legend=True)
china_time_series.plot(legend=True)
india_time_series.plot(title="Total Cases by Country", xlabel="Time (Months)", ylabel="Total Cases", legend=True)
# Out:
# <Axes: title={'center': 'Total Cases by Country'}, xlabel='Time (Months)', ylabel='Total Cases'>

# %% [markdown]
# We can also calculate the **first derivative** of the curve, or the **infection rate**, for any country and plot it
#
#
# The derivative  $f'(a)$ of the function $f(x)$ at the point $x=a$ is the limit
#
# $$f'(a) = \lim{x \to a} \frac{f(x) - f(a)}{x - a}$$
#
#
# Here we will do this with the two countries presented above: `Brazil` and the `United States`. We can set variables named `country_infection_rate` for each country similar to how we made the time series above.
#
# To calculate the first derivative, we can use the pandas command `.diff()`, for each country. This makes it easy to extract the infection rate data we want to analyze.

# %%
# CODE for brazil_infection_rate and us_infection_rate is shown below

brazil_infection_rate = corona_dataset_aggregated_sum.loc['Brazil'].diff()

us_infection_rate = corona_dataset_aggregated_sum.loc['United States'].diff()

# %% [markdown]
# From the code provided in the previous cell, extract the data pertaining to the infection numbers for `India` and `China` in the cell below. Make sure to include a legend and set up the x-axis to label the beginning of every month.

# %%
# YOUR CODE HERE
india_infection_rate = corona_dataset_aggregated_sum.loc['India'].diff()
china_infection_rate = corona_dataset_aggregated_sum.loc['China'].diff()

# %%
type(china_infection_rate)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Complete the code using your knowledge of **matplotlib** to plot data pertaining to the infection numbers of `Brazil`, `India` and `USA` in the cell below

# %%
brazil_infection_rate.plot()
india_infection_rate.plot()
china_infection_rate.plot()
# Out:
# <Axes: >

# %% [markdown]
# Now that we have infection rate data, we can find the maxmimum infection rate for the countries (in terms of infectioned cases per day).
#
# To do this, we will utilize the `.max()` command, which will return the highest number in the dataframe for each country's infection rate array. We are calling these values by the variable we have named `max_inf_country` and printing the value.

# %%
#Run this cell!
max_inf_brazil = corona_dataset_aggregated_sum.loc['Brazil'].diff().max()
print('Maximum infection rate in Brazil = ', max_inf_brazil)
# Out:
# Maximum infection rate in Brazil =  69074.0

# %% [markdown]
# From the code provided in the previous cell, extract the data pertaining to maxmimum infection rate for `US` and `India` and print the values in the cell below

# %%
# YOUR CODE HERE
max_inf_us = corona_dataset_aggregated_sum.loc['United States'].diff().max()
max_inf_india = corona_dataset_aggregated_sum.loc['India'].diff().max()

# %% [markdown]
# We can find the maximum infection rate for all the countries by implementing a **for loop** and **appending** our original data frame
#
# First, we can set a variable, `countries`, as a list of all the countries represented in the dataframe. The next step is to create an open array for the maximum infection rates we will calculate. To do that, all that is needed is a new variable, `max_infection_rates`, and open brackets `[]`.
#
#
# The **for loop** provided below will then be used to **append**, or add, a maximum infection rate column of data to the dataframe we have been working with, `corona_dataset_aggregated_sum`.

# %%
countries = list(corona_dataset_aggregated_sum.index)

max_infection_rates = []
for country in countries:
    max_infection_rates.append(corona_dataset_aggregated_sum.loc[country].diff().max())

corona_dataset_aggregated_sum['max infection rate'] = max_infection_rates

# %% [markdown]
# Preview of the data frame sing the `.head()` command
#
# **Hint:** Remember to put the variable name before the "."

# %%
# YOUR CODE HERE
corona_dataset_aggregated_sum.head()
# Out:
#                 1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# Country/Region
# Afghanistan             0          0          0          0          0
# Albania                 0          0          0          0          0
# Algeria                 0          0          0          0          0
# Andorra                 0          0          0          0          0
# Angola                  0          0          0          0          0
#
#                 1/27/2020  1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  \
# Country/Region                                                         ...
# Afghanistan             0          0          0          0          0  ...
# Albania                 0          0          0          0          0  ...
# Algeria                 0          0          0          0          0  ...
# Andorra                 0          0          0          0          0  ...
# Angola                  0          0          0          0          0  ...
#
# ...

# %% [markdown]
# ## What did you learn about the data after running code in the cell(s) above?
#
# We have successfully added a 223rd column to the data, labeled "max infection rate". It is located at the very end of the data frame columns.
#
# ---

# %% [markdown]
# **YOUR ANSWER HERE**. I learned a lot about how to extract data and do calculations on it

# %% [markdown]
# ---
# Now we can extract the data we need from the main dataframe to create a new one
#
# Here we can do that for the country/regions and the max infection rate.

# %%
corona_max_infection = pd.DataFrame(corona_dataset_aggregated_sum['max infection rate'])

# %%
corona_max_infection.columns
# Out:
# Index(['max infection rate'], dtype='object')

# %%
labels = np.array(df.loc[:, "Country/Region"])

# %% [markdown]
# Now that we have created a new dataframe listing the country/region and their maximum infection rate, plot the maximum infection rate for all the countries below
#
#
#
# **Hint:** You can use the variable we just created, `corona_max_infection`, to plot the country with its maximum rate

# %% [markdown]
# Complete the code using your knowledge of **matplotlib** to plot data pertaining to the maximum infection rates for all countries in the cell below. Make sure to include a legend and set up the x-axis to label at least 4 of the countries with the highest peaks!

# %%
# YOUR CODE HERE
# corona_max_infection.plot(kind="bar")

# Remove the double US reference
corona = corona_max_infection
corona.loc["United States"] = corona.loc["United States"] + corona.loc["US"]

## Drop extra row (this is OK because we added the old value to .loc['United States'])
corona.loc["US"] = 0

agg_sum = corona_dataset_aggregated_sum

max_inf_us = agg_sum.loc['United States'].diff().max() + agg_sum.loc['US'].diff().max()
max_inf_france = agg_sum.loc['France'].diff().max()

x = ["United States", "Brazil", "India", "France"]
y = [max_inf_us, max_inf_brazil, max_inf_india, max_inf_france]

fig, ax = plt.subplots()

ax.plot(corona)

ax.scatter(x, y, color="red")

for num in range(len(x)):
    ax.annotate(text=x[num], xy=(x[num], y[num]))

# %%
pd.set_option('display.max_rows', None)
display(corona)
# Out:
#                                   max infection rate
# Country/Region
# Afghanistan                                    915.0
# Albania                                        178.0
# Algeria                                        675.0
# Andorra                                         79.0
# Angola                                         100.0
# Antigua and Barbuda                             39.0
# Argentina                                    11717.0
# Armenia                                        771.0
# Australia                                      716.0
# Austria                                       1321.0
# Azerbaijan                                     590.0
# Bahamas                                        292.0
# Bahrain                                        786.0
# Bangladesh                                    4019.0
# Barbados                                        12.0
# Belarus                                        973.0
# ...

# %%
corona_max_infection.loc["United States"] = corona_max_infection.loc["United States"] + corona_max_infection.loc["United States"]

# %% [markdown]
# ## Congrats!!
# You completed the Guided Python Project in CS 1010! Give yourself a round of applause!!
