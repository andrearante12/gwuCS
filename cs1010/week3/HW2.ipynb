# %% [markdown]
# # CS1010 Assignment 2
# ### Instructor:
# **Prof. Kartik Bulusu [CS & MAE]**
#
# ### GTA:
# **Oscar Southwell**
#
# ### UTA:
# **Sameen Ahmad, Talia Novack**
#
# ### LA:
# **Manue Alaimo, Selman Eris, Saif Alzaabi, Gustavo Londono, Amy Longua, Pravin Khanal**
#
# ### Grader:
# **Rutvik Solanki**

# %% [markdown]
# Put your name in the below cell inside the quotation marks!

# %%
#Your names go here!
name1 = 'Andre'

print('Group member 1 is named ' + name1)
# Out:
# Group member 1 is named Andre

# %%
#Please use 'Shift+Enter' to execute this cell
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Question 1.
# Estblish a numpy array corresponding to the list `[10, 14, -8, 65, -12]` and call the array `my_arr`
#
# Then use `my_arr` to calculate an array for the following function and save it to `calc_arr`:
#
# $result = \frac{\cos(arr) + 28}{(32)(arr)}$
#
# Please print `calc_arr`
#
# **Hint**: use `np.cos()` to calculate the cosine

# %%
# YOUR CODE HERE
my_arr = np.array([10, 14, -8, 65, -12])
cosine = np.cos(my_arr)
calc_arr = (cosine+28)/32*my_arr
print(calc_arr)
# Out:
# [  8.48779015  12.30982253  -6.96362499  55.73251561 -10.81644523]

# %% [markdown]
# ## Question 2.
# Enter the following matrices. Create a matrix, D, that is the product of matrices A, B, and C.
#
# (i.e., $D=A \cdot B\cdot C$)
#
# A= $\begin{bmatrix} 2&6 \\ 3&9 \end{bmatrix}$,
#
# B=$\begin{bmatrix} 1&2 \\ 3&4 \end{bmatrix}$,
#
# C=$\begin{bmatrix} -5&5 \\ 5&3 \end{bmatrix}$
#
#
# **Hint 1:** Use `np.array()` to create matrices. For eg., `A = np.array([[row1],[row2]])`
#
# **Hint 2:** Use the `np.dot()` command to multiply matrices.
# Only two arguments are allowed at once. Which means you must find the product of two of the matrices first, and then the third.

# %%
# YOUR CODE HERE
A = np.array([[2, 6], [3, 9]])
B = np.array([[1, 2], [3, 4]])
C = np.array([[-5, 5], [5, 3]])
D = np.array(np.dot(np.dot(A, B), C))
print(D)
# Out:
# [[ 40 184]
#  [ 60 276]]

# %% [markdown]
# ## Question 3.
# Using the provided filename, pull the data into a pandas dataframe using `pd.read_csv()` and save it to `df`

# %%
# YOUR CODE HERE
df = pd.read_csv("/Users/andrearante/Documents/fall23/cs1010/week3/apsc1001_cs1010_400mgml_flow.csv", encoding="cp1252")
df
# Out:
#     Stress (Pa)  Shear rate (1/s)  Viscosity (Pa-s)  Step time (s)  \
# 0      0.005925          0.999973          0.005925        61.5517
# 1      0.004771          1.259010          0.003789        92.6491
# 2      0.006430          1.584910          0.004057       153.7600
# 3      0.005794          1.995190          0.002904       174.8430
# 4      0.006895          2.511820          0.002745       236.0050
# 5      0.009995          3.162910          0.003160       297.1440
# 6      0.003783          3.981010          0.000950       358.2820
# 7      0.005628          5.011920          0.001123       419.4290
# 8      0.007715          6.309610          0.001223       460.6400
# 9      0.008329          7.943270          0.001049       511.8200
# 10     0.009810          9.999960          0.000981       553.0030
# 11     0.011585         12.589300          0.000920       614.1290
# 12     0.013719         15.848900          0.000866       660.2830
# 13     0.017957         19.952600          0.000900       701.4110
# 14     0.021931         25.118800          0.000873       727.4910
# 15     0.028546         31.622700          0.000903       753.5630
# 16     0.034918         39.810700          0.000877       774.6220
# 17     0.042687         50.118600          0.000852       795.6760
# 18     0.052921         63.095600          0.000839       816.7190
# 19     0.066353         79.432800          0.000835       837.8000
# 20     0.083066        100.000000          0.000831       858.9770
# 21     0.103923        125.893000          0.000825       880.0980
# 22     0.129903        158.489000          0.000820       901.2470
# 23     0.162872        199.526000          0.000816       922.3470
# 24     0.204469        251.189000          0.000814       948.4360
# 25     0.256610        316.228000          0.000811       974.5100
# 26     0.322304        398.107000          0.000810       995.5740
# 27     0.404817        501.187000          0.000808      1016.6500
# 28     0.508550        630.956000          0.000806      1042.7300
# 29     0.639976        794.328000          0.000806      1063.7600
# 30     0.806146        999.999000          0.000806      1089.8100
# 31     1.018120       1258.920000          0.000809      1110.8700
# 32     1.289310       1584.890000          0.000814      1131.9300
# 33     1.642330       1995.260000          0.000823      1152.9900
# 34     2.108820       2511.890000          0.000840      1174.0500
# 35     2.732830       3162.280000          0.000864      1195.1200
# 36     3.581700       3981.070000          0.000900      1216.2500
# 37     4.753260       5011.870000          0.000948      1237.3400
# 38     6.391900       6309.560000          0.001013      1258.4700
# 39     8.701040       7943.260000          0.001095      1279.5900
# 40    11.949600       9999.990000          0.001195      1300.6700
#
#     Temperature (°C)  Normal stress (Pa)
# 0             21.995            -400.327
# 1             22.002            -402.985
# 2             22.000            -374.586
# 3             21.993            -366.070
# 4             21.997            -382.443
# 5             21.999            -406.933
# 6             21.993            -413.655
# 7             22.008            -420.672
# 8             21.995            -432.273
# 9             22.001            -438.370
# 10            22.000            -449.453
# 11            22.002            -455.315
# 12            21.998            -460.562
# 13            22.005            -460.750
# 14            21.996            -467.946
# 15            22.002            -464.997
# 16            22.001            -467.132
# 17            22.004            -467.253
# 18            22.003            -468.621
# 19            21.998            -468.070
# 20            22.000            -469.273
# 21            21.999            -470.498
# 22            22.001            -469.674
# 23            22.003            -471.146
# 24            21.998            -475.320
# 25            22.003            -476.564
# 26            22.003            -478.566
# 27            22.005            -482.314
# 28            21.998            -483.757
# 29            22.006            -488.599
# 30            22.005            -494.826
# 31            22.001            -502.801
# 32            22.000            -518.193
# 33            21.994            -539.781
# 34            21.995            -576.911
# 35            21.994            -636.906
# 36            21.995            -728.728
# 37            21.998            -873.259
# 38            21.997           -1098.370
# 39            22.002           -1443.440
# 40            21.996           -2035.660

# %% [markdown]
# ## Question 4.
# Plot the column `Stress (Pa)` on the y-axis and column `Shear rate (1/s)` on the x-axis.
#
# **Hint 1:** Use `df.loc[:,'Column Name'].values` to convert the column into a numpy array
#
# **Hint 2:** Use `plt.plot(x, y)` to plot the data from those arrays

# %%
# YOUR CODE HERE
y = df.loc[:,'Stress (Pa)'].values
x = df.loc[:, 'Shear rate (1/s)']
plt.plot(x, y)

# %%
print("Welcome to", end=' ') # There is a space in between the single-quotes
print("CS1010", end='') # There is no space in between the single-quote
# Out:
# Welcome to CS1010

# %% [markdown]
# ## Congrats!!
#  You completed your 2nd Python Assignment in CS 1010! Give yourself a round of applause!!

# %% [markdown]
# ### Below cells are part of test section that will run your code against some test cases, **DO NOT** interact with these cells.
# ### If you add anything in these cells, your might end up scoring a 0 for this assignment.
