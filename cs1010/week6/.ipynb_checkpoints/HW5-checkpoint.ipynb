# %% [markdown]
# # CS1010 Assignment 5
# ### Instructor:
# **Prof. Kartik Bulusu [CS & MAE]**
#
# ### GTA:
# **Oscar Southwell**
#
# ### UTA:
# **Sameen Ahmad, Talia Novack**
#
# ### LA:
# **Manue Alaimo, Selman Eris, Saif Alzaabi, Gustavo Londono, Amy Longua, Pravin Khanal**
#
# ### Grader:
# **Rutvik Solanki**

# %%
#Please use 'Shift+Enter' to execute this cell
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import PIL

# %% [markdown]
# Put your name in the below cell inside the quotation marks!

# %%
#Your name goes here!
name = 'Andre'

print('Assignemnt is submitted by ' + name)
# Out:
# Assignemnt is submitted by Andre

# %% [markdown]
# ## Question 1.
#
# We have provided a homework picture file in the Week6 folder named `HW5.png`, pull this data into a image object named `im` using `PIL.Image.open(FILEPATH)`

# %%
# YOUR CODE HERE
im = PIL.Image.open('HW5.png')

# %% [markdown]
# ## Question 2.
#
# Convert the image object to grayscale using `im.convert('L')` and save this once again as `im`. Then use `np.array(im, dtype='int16')` to save this object to a numpy array named `HW5_pic`

# %%
# YOUR CODE HERE
im = im.convert('L')
HW5_pic = np.array(im, dtype='int16')

# %% [markdown]
# ## Question 3.
#
# 1. Set up a 1x1 subplot using `fig, ax = plt.subplots(figsize=(WIDTH, HEIGHT))`. Choose a figsize that looks good!
#
# 2. Set a title for your image: "Homework 5 Grayscale"
#
# 3. Use `.imshow()` and an appropriate axis and cmap to show the grayscale image with matplotlib

# %%
# YOUR CODE HERE
fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(HW5_pic, cmap='gray');

# %% [markdown]
# ## Question 4.
#
# Set up an input for a key using Option 1 from the Demo5-Guide. Save the key to `k`. Give the value of 168 to the input

# %%
# YOUR CODE HERE
k = int(input("What is your encryption key? Enter a value between 1 and 250: "))
# Out:
# What is your encryption key? Enter a value between 1 and 250: 168

# %% [markdown]
# ## Question 5.
#
# Run the encryption code we have provided, then show the encrypted image

# %%
for i in range(HW5_pic.shape[0]):
    for j in range(HW5_pic.shape[1]):
        HW5_pic[i][j] = (HW5_pic[i][j] + k) % 256 

# YOUR CODE HERE

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title('The Encrypted Image', fontsize=10)
ax.imshow(HW5_pic, cmap='gray')

# %% [markdown]
# ## Question 6.
#
# Use the nested for-loop method to decrypt the image. Then use the code we have provided to show the decrypted image.
#
# **Hint**: your image should match the initial image you showed in Question 3. If it doesn't, try clicking the **Run All Cells** button under the **Run** tab on the toolbar to rerun the cells. You will need to enter 168 again in **Question 4**.

# %%
# YOUR CODE HERE

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title('The Decrypted Image', fontsize=10)
HW5_pic = np.remainder(HW5_pic - k, 256)
ax.imshow(HW5_pic, cmap='gray')

# %% [markdown]
# ## Question 7.
#
# #### Conceptual question - No Code!
#
# Is the encryption weak or strong?
#
# How could you improve the strength of the encryption?
#
# ---
#
# Weak because it is all based on a single key that is fairly easy to guess based on the strength of the encryption

# %% [markdown]
# **YOUR ANSWER HERE**. _Double-click here to begin writting, and replace this text with your answer._

# %% [markdown]
# ---
#
# ## Congrats!!
#  You completed your 5th Python Assignment in CS 1010! Give yourself a round of applause!!
